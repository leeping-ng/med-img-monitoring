# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from config import load_config

CONFIG_PATH = "config.yml"
TRANSFORMS = ["Blur", "Sharpen", "Salt Pepper Noise", "Speckle Noise", "Contrast Inc", "Contrast Dec", "Gamma Inc", "Gamma Dec", "Magnify"]

configs = load_config(CONFIG_PATH)

df = pd.read_csv(configs["plot"]["csv_path"])

INTERVALS = [0, 12.5, 25, 50, 100]*(df.shape[0]//5)
df["Shift Intensity"] = INTERVALS

# %%
pd.set_option('display.max_rows', df.shape[0])
df
# Out:
#                       Transform  K-S SM signal   K-S SM pval  K-S SM acc
# 0                Blur Unchanged        0.00000  1.000000e+00         0.0  \
# 1                    Blur 12.5%        0.23050  1.121146e-08         1.0
# 2                      Blur 25%        0.41625  2.092199e-25         1.0
# 3                      Blur 50%        0.55250  1.019237e-49         1.0
# 4                     Blur 100%        0.59700  6.702854e-58         1.0
# 5             Sharpen Unchanged        0.00000  1.000000e+00         0.0
# 6                 Sharpen 12.5%        0.27525  6.862657e-11         1.0
# 7                   Sharpen 25%        0.48225  3.447603e-36         1.0
# 8                   Sharpen 50%        0.56900  1.043129e-51         1.0
# 9                  Sharpen 100%        0.56400  4.121460e-52         1.0
# 10  Salt Pepper Noise Unchanged        0.00000  1.000000e+00         0.0
# 11      Salt Pepper Noise 12.5%        0.60850  1.460890e-63         1.0
# 12        Salt Pepper Noise 25%        0.66675  2.141767e-76         1.0
# 13        Salt Pepper Noise 50%        0.67275  2.117856e-76         1.0
# 14       Salt Pepper Noise 100%        0.70325  2.012817e-86         1.0
# 15      Speckle Noise Unchanged        0.00000  1.000000e+00         0.0
# 16          Speckle Noise 12.5%        0.40350  4.636234e-26         1.0
# 17            Speckle Noise 25%        0.51850  1.694231e-43         1.0
# 18            Speckle Noise 50%        0.63300  1.140922e-67         1.0
# 19           Speckle Noise 100%        0.71275  1.262020e-88         1.0
# 20       Contrast Inc Unchanged        0.00000  1.000000e+00         0.0
# 21           Contrast Inc 12.5%        0.06875  3.168696e-01         0.0
# 22             Contrast Inc 25%        0.14175  1.806858e-03         1.0
# 23             Contrast Inc 50%        0.25300  8.744124e-10         1.0
# 24            Contrast Inc 100%        0.33525  1.759176e-16         1.0
# 25       Contrast Dec Unchanged        0.00000  1.000000e+00         0.0
# 26           Contrast Dec 12.5%        0.01825  9.999924e-01         0.0
# 27             Contrast Dec 25%        0.02700  9.902585e-01         0.0
# 28             Contrast Dec 50%        0.05975  4.804731e-01         0.0
# 29            Contrast Dec 100%        0.64375  2.700550e-68         1.0
# 30          Gamma Inc Unchanged        0.00000  1.000000e+00         0.0
# 31              Gamma Inc 12.5%        0.07750  1.863853e-01         0.0
# 32                Gamma Inc 25%        0.10000  5.989315e-02         0.3
# 33                Gamma Inc 50%        0.25500  6.208307e-09         1.0
# 34               Gamma Inc 100%        0.45425  4.658184e-31         1.0
# 35          Gamma Dec Unchanged        0.00000  1.000000e+00         0.0
# 36              Gamma Dec 12.5%        0.04250  8.555015e-01         0.0
# 40          0.00000           0.0       0.000000  1.000000e+00         0.0
# 41          0.04300           0.0       0.702094  5.119728e-01         0.0
# 42          0.05175           0.0       0.887802  4.724596e-01         0.0
# 43          0.14850           1.0       0.433367  5.317191e-01         0.0
# 44          0.46525           1.0       1.088714  4.202841e-01         0.0
#
#     Shift Intensity
# 0               0.0
# 1              12.5
# 2              25.0
# 3              50.0
# 4             100.0
# 5               0.0
# 6              12.5
# 7              25.0
# 8              50.0
# 9             100.0
# 10              0.0
# 11             12.5
# 12             25.0
# 13             50.0
# 14            100.0
# 15              0.0
# 16             12.5
# 17             25.0
# 18             50.0
# 19            100.0
# 20              0.0
# 21             12.5
# 22             25.0
# 23             50.0
# 24            100.0
# 25              0.0
# 26             12.5
# 27             25.0
# 28             50.0
# 29            100.0
# 30              0.0
# 31             12.5
# 32             25.0
# 33             50.0
# 34            100.0
# 35              0.0
# 36             12.5
# 37             25.0
# 38             50.0
# 39            100.0
# 40              0.0
# 41             12.5
# 42             25.0
# 43             50.0
# 44            100.0

# %%
dataframes = []
# create a separate df for each transform
for transform in TRANSFORMS:
    dataframes.append(df.loc[df["Transform"].str.contains(transform)])
dataframes[0]
# Out:
#         Transform  K-S SM signal   K-S SM pval  K-S SM acc  K-S conf signal
# 0  Blur Unchanged        0.00000  1.000000e+00         0.0          0.00000  \
# 1      Blur 12.5%        0.23050  1.121146e-08         1.0          0.23950
# 2        Blur 25%        0.41625  2.092199e-25         1.0          0.44500
# 3        Blur 50%        0.55250  1.019237e-49         1.0          0.59750
# 4       Blur 100%        0.59700  6.702854e-58         1.0          0.65125
#
#    K-S conf acc  Chi-Sq signal   Chi-Sq pval  Chi-Sq acc  Shift Intensity
# 0           0.0       0.000000  1.000000e+00         0.0              0.0
# 1           1.0       6.682132  3.498333e-02         0.8             12.5
# 2           1.0      40.085802  4.787686e-09         1.0             25.0
# 3           1.0      74.739873  5.716215e-15         1.0             50.0
# 4           1.0      74.739873  5.716215e-15         1.0            100.0

# %%
for df_tf in dataframes:
    plt.plot(df_tf["Shift Intensity"], df_tf["K-S SM signal"])
plt.legend(TRANSFORMS, bbox_to_anchor=(1.05, 1.0), loc="upper left")
plt.title("K-S Test on Softmax Inputs: Response to Transforms")
plt.xlabel("Shift Intensity")
plt.ylabel("K-S signal")
plt.show()

# %%
for df_tf in dataframes:
    plt.plot(df_tf["Shift Intensity"], df_tf["K-S SM acc"], alpha=0.8)

plt.legend(TRANSFORMS, bbox_to_anchor=(1.05, 1.0), loc="upper left")
plt.title("K-S Test on Softmax Inputs: Shift Detection Accuracy")
plt.xlabel("Shift Intensity")
plt.ylabel("K-S Accuracy")
plt.show()

# %%
for df_tf in dataframes:
    plt.plot(df_tf["Shift Intensity"], df_tf["K-S conf signal"])
plt.legend(TRANSFORMS, bbox_to_anchor=(1.05, 1.0), loc="upper left")
plt.title("K-S Test on Confidence Scores: Response to Transforms")
plt.xlabel("Shift Intensity")
plt.ylabel("K-S signal")
plt.show()

# %%
for df_tf in dataframes:
    plt.plot(df_tf["Shift Intensity"], df_tf["K-S conf acc"], alpha=0.8)

plt.legend(TRANSFORMS, bbox_to_anchor=(1.05, 1.0), loc="upper left")
plt.title("K-S Test on Confidence Scores: Shift Detection Accuracy")
plt.xlabel("Shift Intensity")
plt.ylabel("K-S Accuracy")
plt.show()

# %%
for df_tf in dataframes:
    plt.plot(df_tf["Shift Intensity"], df_tf["Chi-Sq signal"])
plt.legend(TRANSFORMS, bbox_to_anchor=(1.05, 1.0), loc="upper left")
plt.title("Chi-Sq Test on Predicted Labels: Response to Transforms")
plt.xlabel("Shift Intensity")
plt.ylabel("Chi-Sq signal")
plt.show()

# %%
for df_tf in dataframes:
    plt.plot(df_tf["Shift Intensity"], df_tf["Chi-Sq acc"], alpha=0.8)

plt.legend(TRANSFORMS, bbox_to_anchor=(1.05, 1.0), loc="upper left")
plt.title("Chi-Sq Test on Predicted Labels: Shift Detection Accuracy")
plt.xlabel("Shift Intensity")
plt.ylabel("Chi-Sq Accuracy")
plt.show()
