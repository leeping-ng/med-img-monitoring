# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from config import load_config

CONFIG_PATH = "config.yml"
TRANSFORMS = ["Blur", "Sharpen", "Salt Pepper Noise", "Speckle Noise", "Contrast Inc", "Contrast Dec", "Gamma Inc", "Gamma Dec", "Magnify"]

configs = load_config(CONFIG_PATH)

df = pd.read_csv(configs["plot"]["csv_path"])

# INTERVALS = [0, 12.5, 25, 50, 100]*(df.shape[0]//5)
# df["Shift Intensity"] = INTERVALS

# %%
pd.set_option('display.max_rows', df.shape[0])
df
# Out:
#                      Transform  K-S SM signal   K-S SM pval  K-S SM acc
# 0                Blur AUC 0.86        0.00000  1.000000e+00         0.0  \
# 1                Blur AUC 0.85        0.14700  8.339704e-04         1.0
# 2                Blur AUC 0.84        0.20575  3.211725e-07         1.0
# 3                Blur AUC 0.83        0.28050  9.686111e-12         1.0
# 4                Blur AUC 0.82        0.36225  4.053988e-19         1.0
# 5                Blur AUC 0.78        0.50700  5.336910e-41         1.0
# 6                Blur AUC 0.74        0.55250  1.019237e-49         1.0
# 7                Blur AUC 0.70        0.58350  2.987296e-54         1.0
# 8             Sharpen AUC 0.86        0.00000  1.000000e+00         0.0
# 9             Sharpen AUC 0.85        0.14050  1.128861e-03         1.0
# 10            Sharpen AUC 0.84        0.24975  1.373209e-08         1.0
# 11            Sharpen AUC 0.83        0.29375  3.648935e-12         1.0
# 12            Sharpen AUC 0.82        0.35050  2.777117e-17         1.0
# 13            Sharpen AUC 0.78        0.48625  5.185306e-37         1.0
# 14            Sharpen AUC 0.74        0.53050  5.338712e-44         1.0
# 15            Sharpen AUC 0.70        0.56200  4.258607e-50         1.0
# 16            Sharpen AUC 0.66        0.56800  4.203878e-52         1.0
# 17  Salt Pepper Noise AUC 0.86        0.00000  1.000000e+00         0.0
# 18  Salt Pepper Noise AUC 0.85        0.22175  5.388333e-08         1.0
# 19  Salt Pepper Noise AUC 0.84        0.30650  1.184967e-14         1.0
# 20  Salt Pepper Noise AUC 0.83        0.37350  1.457318e-21         1.0
# 21  Salt Pepper Noise AUC 0.82        0.43550  3.504099e-30         1.0
# 22  Salt Pepper Noise AUC 0.78        0.58975  4.751474e-60         1.0
# 23  Salt Pepper Noise AUC 0.74        0.64775  2.451440e-71         1.0
# 24  Salt Pepper Noise AUC 0.70        0.66425  4.823357e-77         1.0
# 25  Salt Pepper Noise AUC 0.66        0.68275  2.406181e-82         1.0
# 26  Salt Pepper Noise AUC 0.62        0.68225  5.140680e-79         1.0
# 27  Salt Pepper Noise AUC 0.58        0.70650  1.631503e-86         1.0
# 28      Speckle Noise AUC 0.86        0.00000  1.000000e+00         0.0
# 29      Speckle Noise AUC 0.85        0.10475  4.110378e-02         0.6
# 30      Speckle Noise AUC 0.84        0.16600  1.354532e-04         1.0
# 31      Speckle Noise AUC 0.83        0.23825  1.452145e-08         1.0
# 32      Speckle Noise AUC 0.82        0.30300  3.649503e-14         1.0
# 33      Speckle Noise AUC 0.78        0.44475  1.089384e-31         1.0
# 34      Speckle Noise AUC 0.74        0.56650  9.714824e-53         1.0
# 35      Speckle Noise AUC 0.70        0.65075  4.102248e-70         1.0
# 36      Speckle Noise AUC 0.66        0.71875  1.217281e-88         1.0
# 37      Speckle Noise AUC 0.62        0.61400  6.979736e-62         1.0
# 38      Speckle Noise AUC 0.58        0.61400  2.721999e-63         1.0
# 39       Contrast Inc AUC 0.86        0.00000  1.000000e+00         0.0
# 40       Contrast Inc AUC 0.85        0.09200  8.338740e-02         0.0
# 41       Contrast Inc AUC 0.84        0.11750  1.463662e-02         0.8
# 42       Contrast Inc AUC 0.83        0.13725  2.796780e-03         1.0
# 43       Contrast Inc AUC 0.82        0.16975  1.660442e-04         1.0
# 44       Contrast Inc AUC 0.78        0.25300  8.744124e-10         1.0
# 45       Contrast Inc AUC 0.74        0.28700  2.007894e-13         1.0
# 46       Contrast Inc AUC 0.70        0.31350  1.172384e-15         1.0
# 47       Contrast Inc AUC 0.66        0.35450  1.493503e-17         1.0
# 48       Contrast Inc AUC 0.62        0.44875  1.102190e-30         1.0
# 49       Contrast Inc AUC 0.58        0.48650  5.455681e-37         1.0
# 50       Contrast Dec AUC 0.86        0.00000  1.000000e+00         0.0
# 51       Contrast Dec AUC 0.85        0.20750  7.309046e-07         1.0
# 52       Contrast Dec AUC 0.84        0.28875  2.490660e-12         1.0
# 53       Contrast Dec AUC 0.83        0.33950  2.298837e-17         1.0
# 54       Contrast Dec AUC 0.82        0.37350  4.223977e-21         1.0
# 55       Contrast Dec AUC 0.78        0.48325  1.038574e-37         1.0
# 56       Contrast Dec AUC 0.74        0.52950  7.303819e-46         1.0
# 57       Contrast Dec AUC 0.70        0.58125  2.143424e-56         1.0
# 58       Contrast Dec AUC 0.66        0.61500  5.077729e-63         1.0
# 59       Contrast Dec AUC 0.62        0.63400  1.657422e-66         1.0
# 60       Contrast Dec AUC 0.58        0.65400  1.000080e-70         1.0
# 61          Gamma Inc AUC 0.86        0.00000  1.000000e+00         0.0
# 62          Gamma Inc AUC 0.85        0.07250  2.626348e-01         0.0
# 63          Gamma Inc AUC 0.84        0.09000  1.009281e-01         0.2
# 64          Gamma Inc AUC 0.83        0.13325  9.044227e-03         0.8
# 65          Gamma Inc AUC 0.82        0.16000  7.618876e-04         1.0
# 66          Gamma Inc AUC 0.78        0.25900  4.044976e-09         1.0
# 67          Gamma Inc AUC 0.74        0.35050  4.620794e-18         1.0
# 68          Gamma Inc AUC 0.70        0.42850  1.085110e-26         1.0
# 69          Gamma Inc AUC 0.66        0.47950  5.691718e-35         1.0
# 70          Gamma Inc AUC 0.62        0.51000  1.003896e-41         1.0
# 71          Gamma Inc AUC 0.58        0.53000  3.365023e-46         1.0
# 72          Gamma Dec AUC 0.86        0.00000  1.000000e+00         0.0
# 73          Gamma Dec AUC 0.85        0.27275  2.565047e-12         1.0
# 74          Gamma Dec AUC 0.84        0.33175  5.845615e-18         1.0
# 75          Gamma Dec AUC 0.83        0.36550  3.101037e-21         1.0
# 76          Gamma Dec AUC 0.82        0.39300  1.085050e-24         1.0
# 77          Gamma Dec AUC 0.78        0.46350  4.127370e-34         1.0
# 78          Gamma Dec AUC 0.74        0.49875  8.025539e-39         1.0
# 79          Gamma Dec AUC 0.70        0.52375  1.272730e-42         1.0
# 80          Gamma Dec AUC 0.66        0.53800  7.546486e-46         1.0
# 81          Gamma Dec AUC 0.62        0.54800  1.000681e-47         1.0
# 82          Gamma Dec AUC 0.58        0.55925  3.238443e-49         1.0
# 83            Magnify AUC 0.86        0.00000  1.000000e+00         0.0
# 84            Magnify AUC 0.85        0.17075  9.329856e-05         1.0
# 85            Magnify AUC 0.84        0.23250  2.420784e-08         1.0
# 86            Magnify AUC 0.83        0.28075  2.946016e-12         1.0
# 87            Magnify AUC 0.82        0.31125  3.947516e-15         1.0
# 88            Magnify AUC 0.78        0.37950  8.515740e-20         1.0
# 89            Magnify AUC 0.74        0.43050  8.179325e-28         1.0
# 90            Magnify AUC 0.70        0.46500  1.318582e-32         1.0
# 91            Magnify AUC 0.66        0.49875  1.222285e-38         1.0
# 92            Magnify AUC 0.62        0.53550  2.512034e-46         1.0
# 93            Magnify AUC 0.58        0.56900  1.820333e-53         1.0
#
#     MMD UE signal  MMD UE pval  MMD UE acc  MMD TE signal  MMD TE pval
# 0       -0.003145        1.000         0.0      -0.002923          1.0  \
# 1       -0.002839        1.000         0.0       0.029264          0.0
# 2       -0.002513        1.000         0.0       0.056838          0.0
# 3       -0.001830        1.000         0.0       0.105446          0.0
# 4       -0.000907        0.920         0.0       0.178586          0.0
# 5        0.002326        0.021         0.8       0.328638          0.0
# 6        0.008358        0.000         1.0       0.374818          0.0
# 7        0.039650        0.000         1.0       0.414203          0.0
# 8       -0.003145        1.000         0.0      -0.002923          1.0
# 9        0.005028        0.000         1.0       0.081357          0.0
# 10       0.024752        0.000         1.0       0.143174          0.0
# 11       0.035763        0.000         1.0       0.168903          0.0
# 12       0.051712        0.000         1.0       0.205527          0.0
# 13       0.108623        0.000         1.0       0.327759          0.0
# 14       0.137439        0.000         1.0       0.375410          0.0
# 15       0.173687        0.000         1.0       0.421398          0.0
# 16       0.221892        0.000         1.0       0.464598          0.0
# 17      -0.003145        1.000         0.0      -0.002923          1.0
# 18      -0.003092        1.000         0.0       0.072347          0.0
# 19      -0.003042        1.000         0.0       0.137164          0.0
# 20      -0.002973        1.000         0.0       0.198800          0.0
# 21      -0.002861        1.000         0.0       0.259011          0.0
# 22      -0.001947        1.000         0.0       0.394373          0.0
# 23      -0.000028        0.454         0.0       0.440075          0.0
# 24       0.001972        0.017         1.0       0.452387          0.0
# 25       0.007960        0.000         1.0       0.464321          0.0
# 26       0.037678        0.000         1.0       0.417720          0.0
# 27       0.048988        0.000         1.0       0.420314          0.0
# 28      -0.003145        1.000         0.0      -0.002923          1.0
# 29      -0.003106        1.000         0.0       0.017730          0.0
# 30      -0.003007        1.000         0.0       0.048264          0.0
# 31      -0.002770        1.000         0.0       0.095216          0.0
# 32      -0.002381        1.000         0.0       0.143214          0.0
# 33       0.000338        0.249         0.0       0.274295          0.0
# 34       0.007294        0.000         1.0       0.359163          0.0
# 35       0.020627        0.000         1.0       0.403266          0.0
# 36       0.050673        0.000         1.0       0.425481          0.0
# 37       0.322768        0.000         1.0       0.505345          0.0
# 38       0.337468        0.000         1.0       0.521803          0.0
# 39      -0.003145        1.000         0.0      -0.002923          1.0
# 40       0.117397        0.000         1.0       0.023336          0.0
# 41       0.142127        0.000         1.0       0.041313          0.0
# 42       0.158699        0.000         1.0       0.056404          0.0
# 43       0.182346        0.000         1.0       0.082231          0.0
# 44       0.230684        0.000         1.0       0.154211          0.0
# 45       0.249154        0.000         1.0       0.189366          0.0
# 46       0.262769        0.000         1.0       0.221728          0.0
# 47       0.278606        0.000         1.0       0.275424          0.0
# 48       0.297639        0.000         1.0       0.390072          0.0
# 49       0.303364        0.000         1.0       0.439501          0.0
# 50      -0.003145        1.000         0.0      -0.002923          1.0
# 51       0.278012        0.000         1.0       0.062896          0.0
# 52       0.322519        0.000         1.0       0.112936          0.0
# 53       0.344795        0.000         1.0       0.148561          0.0
# 54       0.359565        0.000         1.0       0.177064          0.0
# 55       0.399503        0.000         1.0       0.275657          0.0
# 56       0.413668        0.000         1.0       0.317525          0.0
# 57       0.427584        0.000         1.0       0.360301          0.0
# 58       0.437837        0.000         1.0       0.390990          0.0
# 59       0.444575        0.000         1.0       0.409381          0.0
# 60       0.454530        0.000         1.0       0.431584          0.0
# 61      -0.003145        1.000         0.0      -0.002923          1.0
# 62       0.315052        0.000         1.0       0.014470          0.0
# 63       0.408118        0.000         1.0       0.026277          0.0
# 64       0.490300        0.000         1.0       0.040218          0.0
# 65       0.539310        0.000         1.0       0.049251          0.0
# 66       0.744981        0.000         1.0       0.092700          0.0
# 67       0.889211        0.000         1.0       0.151859          0.0
# 68       0.987221        0.000         1.0       0.218562          0.0
# 69       1.047198        0.000         1.0       0.267509          0.0
# 70       1.085590        0.000         1.0       0.300403          0.0
# 71       1.110127        0.000         1.0       0.321645          0.0
# 72      -0.003145        1.000         0.0      -0.002923          1.0
# 73       0.445995        0.000         1.0       0.077271          0.0
# 74       0.549482        0.000         1.0       0.117310          0.0
# 75       0.604835        0.000         1.0       0.144148          0.0
# 76       0.642805        0.000         1.0       0.164494          0.0
# 77       0.740210        0.000         1.0       0.219507          0.0
# 78       0.789433        0.000         1.0       0.244685          0.0
# 79       0.838156        0.000         1.0       0.265277          0.0
# 80       0.876209        0.000         1.0       0.279438          0.0
# 81       0.912890        0.000         1.0       0.294956          0.0
# 82       0.947417        0.000         1.0       0.316377          0.0
# 83      -0.003145        1.000         0.0      -0.002923          1.0
# 84       0.171355        0.000         1.0       0.051573          0.0
# 85       0.179627        0.000         1.0       0.086331          0.0
# 86       0.184599        0.000         1.0       0.121448          0.0
# 87       0.187027        0.000         1.0       0.146998          0.0
# 88       0.190822        0.000         1.0       0.212521          0.0
# 89       0.194296        0.000         1.0       0.270429          0.0
# 90       0.196841        0.000         1.0       0.308682          0.0
# 91       0.199825        0.000         1.0       0.337354          0.0
# 92       0.205770        0.000         1.0       0.364153          0.0
# 93       0.213595        0.000         1.0       0.381179          0.0
#
#     MMD TE acc   ROC-AUC
# 0          0.0  0.860981
# 1          1.0  0.843110
# 2          1.0  0.830524
# 3          1.0  0.820803
# 4          1.0  0.809276
# 5          1.0  0.766403
# 6          1.0  0.724283
# 7          1.0  0.684262
# 8          0.0  0.860981
# 9          1.0  0.842707
# 10         1.0  0.829777
# 11         1.0  0.822835
# 12         1.0  0.814103
# 13         1.0  0.759841
# 14         1.0  0.721294
# 15         1.0  0.677330
# 16         1.0  0.637551
# 17         0.0  0.860981
# 18         1.0  0.842718
# 19         1.0  0.837512
# 20         1.0  0.823517
# 21         1.0  0.808466
# 22         1.0  0.767081
# 23         1.0  0.733107
# 24         1.0  0.696346
# 25         1.0  0.644036
# 26         1.0  0.614679
# 27         1.0  0.579507
# 28         0.0  0.860981
# 29         1.0  0.837749
# 30         1.0  0.826405
# 31         1.0  0.812642
# 32         1.0  0.804812
# 33         1.0  0.771169
# 34         1.0  0.731638
# 35         1.0  0.700650
# 36         1.0  0.652764
# 37         1.0  0.627498
# 38         1.0  0.568323
# 39         0.0  0.860981
# 40         1.0  0.836282
# 41         1.0  0.824810
# 42         1.0  0.815551
# 43         1.0  0.807699
# 44         1.0  0.764614
# 45         1.0  0.727511
# 46         1.0  0.687877
# 47         1.0  0.656152
# 48         1.0  0.619704
# 49         1.0  0.570104
# 50         0.0  0.860981
# 51         1.0  0.846440
# 52         1.0  0.836074
# 53         1.0  0.827366
# 54         1.0  0.819495
# 55         1.0  0.778142
# 56         1.0  0.752197
# 57         1.0  0.705259
# 58         1.0  0.659678
# 59         1.0  0.625855
# 60         1.0  0.581153
# 61         0.0  0.860981
# 62         1.0  0.842718
# 63         1.0  0.833639
# 64         1.0  0.820952
# 65         1.0  0.812411
# 66         1.0  0.763136
# 67         1.0  0.716159
# 68         1.0  0.683666
# 69         1.0  0.646610
# 70         1.0  0.609944
# 71         1.0  0.587466
# 72         0.0  0.860981
# 73         1.0  0.850606
# 74         1.0  0.840664
# 75         1.0  0.830775
# 76         1.0  0.821805
# 77         1.0  0.780958
# 78         1.0  0.748236
# 79         1.0  0.699769
# 80         1.0  0.656359
# 81         1.0  0.616489
# 82         1.0  0.583749
# 83         0.0  0.860981
# 84         1.0  0.847819
# 85         1.0  0.837288
# 86         1.0  0.824489
# 87         1.0  0.812199
# 88         1.0  0.777051
# 89         1.0  0.734528
# 90         1.0  0.697873
# 91         1.0  0.657671
# 92         1.0  0.614966
# 93         1.0  0.568058

# %%
dataframes = []
# create a separate df for each transform
for transform in TRANSFORMS:
    dataframes.append(df.loc[df["Transform"].str.contains(transform)])
dataframes[0]
# Out:
#        Transform  K-S SM signal   K-S SM pval  K-S SM acc  MMD UE signal
# 0  Blur AUC 0.86        0.00000  1.000000e+00         0.0      -0.003145  \
# 1  Blur AUC 0.85        0.14700  8.339704e-04         1.0      -0.002839
# 2  Blur AUC 0.84        0.20575  3.211725e-07         1.0      -0.002513
# 3  Blur AUC 0.83        0.28050  9.686111e-12         1.0      -0.001830
# 4  Blur AUC 0.82        0.36225  4.053988e-19         1.0      -0.000907
# 5  Blur AUC 0.78        0.50700  5.336910e-41         1.0       0.002326
# 6  Blur AUC 0.74        0.55250  1.019237e-49         1.0       0.008358
# 7  Blur AUC 0.70        0.58350  2.987296e-54         1.0       0.039650
#
#    MMD UE pval  MMD UE acc  MMD TE signal  MMD TE pval  MMD TE acc   ROC-AUC
# 0        1.000         0.0      -0.002923          1.0         0.0  0.860981
# 1        1.000         0.0       0.029264          0.0         1.0  0.843110
# 2        1.000         0.0       0.056838          0.0         1.0  0.830524
# 3        1.000         0.0       0.105446          0.0         1.0  0.820803
# 4        0.920         0.0       0.178586          0.0         1.0  0.809276
# 5        0.021         0.8       0.328638          0.0         1.0  0.766403
# 6        0.000         1.0       0.374818          0.0         1.0  0.724283
# 7        0.000         1.0       0.414203          0.0         1.0  0.684262

# %%
for df_tf in dataframes:
    plt.plot(df_tf["ROC-AUC"], df_tf["K-S SM signal"])
plt.legend(TRANSFORMS, bbox_to_anchor=(1.05, 1.0), loc="upper left")
plt.title("K-S Test on Softmax Inputs: Response to Transforms")
plt.xlabel("ROC-AUC")
plt.ylabel("K-S signal")
plt.show()

# %%
for df_tf in dataframes:
    plt.plot(df_tf["ROC-AUC"], df_tf["MMD UE signal"])
plt.legend(TRANSFORMS, bbox_to_anchor=(1.05, 1.0), loc="upper left")
plt.title("MMD Test on Untrained Encoder Inputs: Response to Transforms")
plt.xlabel("ROC-AUC")
plt.ylabel("MME UE signal")
plt.show()

# %%
for df_tf in dataframes:
    plt.plot(df_tf["ROC-AUC"], df_tf["MMD TE signal"])
plt.legend(TRANSFORMS, bbox_to_anchor=(1.05, 1.0), loc="upper left")
plt.title("MMD Test on Trained Encoder Inputs: Response to Transforms")
plt.xlabel("ROC-AUC")
plt.ylabel("MME TE signal")
plt.show()

# %%
for df_tf in dataframes:
    plt.plot(df_tf["ROC-AUC"], df_tf["K-S SM acc"], alpha=0.8)

plt.legend(TRANSFORMS, bbox_to_anchor=(1.05, 1.0), loc="upper left")
plt.title("K-S Test on Softmax Inputs: Shift Detection Accuracy")
plt.xlabel("ROC-AUC")
plt.ylabel("K-S Accuracy")
plt.show()

# %%
for df_tf in dataframes:
    plt.plot(df_tf["ROC-AUC"], df_tf["MMD UE acc"], alpha=0.8)

plt.legend(TRANSFORMS, bbox_to_anchor=(1.05, 1.0), loc="upper left")
plt.title("MMD Test on Untrained Encoder Inputs: Shift Detection Accuracy")
plt.xlabel("ROC-AUC")
plt.ylabel("MMD UE Accuracy")
plt.show()

# %%
for df_tf in dataframes:
    plt.plot(df_tf["ROC-AUC"], df_tf["MMD TE acc"], alpha=0.8)

plt.legend(TRANSFORMS, bbox_to_anchor=(1.05, 1.0), loc="upper left")
plt.title("MMD Test on Trained Encoder Inputs: Shift Detection Accuracy")
plt.xlabel("ROC-AUC")
plt.ylabel("MMD TE Accuracy")
plt.show()
