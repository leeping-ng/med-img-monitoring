# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from config import load_config

CONFIG_PATH = "config.yml"
TRANSFORMS = ["Blur", "Sharpen", "Salt Pepper Noise", "Speckle Noise", "Contrast Inc", "Contrast Dec", "Gamma Inc", "Gamma Dec", "Magnify"]

configs = load_config(CONFIG_PATH)

df = pd.read_csv(configs["plot"]["csv_path"])

# INTERVALS = [0, 12.5, 25, 50, 100]*(df.shape[0]//5)
# df["Shift Intensity"] = INTERVALS

# %%
pd.set_option('display.max_rows', df.shape[0])
df
# Out:
#                      Transform  K-S SM signal   K-S SM pval  K-S SM acc
# 0                Blur AUC 0.86        0.00000  1.000000e+00         0.0  \
# 1                Blur AUC 0.82        0.36225  4.053988e-19         1.0
# 2                Blur AUC 0.78        0.50700  5.336910e-41         1.0
# 3                Blur AUC 0.74        0.55250  1.019237e-49         1.0
# 4                Blur AUC 0.70        0.58350  2.987296e-54         1.0
# 5             Sharpen AUC 0.86        0.00000  1.000000e+00         0.0
# 6             Sharpen AUC 0.82        0.35050  2.777117e-17         1.0
# 7             Sharpen AUC 0.78        0.48625  5.185306e-37         1.0
# 8             Sharpen AUC 0.74        0.53050  5.338712e-44         1.0
# 9             Sharpen AUC 0.70        0.56200  4.258607e-50         1.0
# 10            Sharpen AUC 0.66        0.56800  4.203878e-52         1.0
# 11  Salt Pepper Noise AUC 0.86        0.00000  1.000000e+00         0.0
# 12  Salt Pepper Noise AUC 0.82        0.43675  2.636961e-29         1.0
# 13  Salt Pepper Noise AUC 0.78        0.59575  4.317774e-60         1.0
# 14  Salt Pepper Noise AUC 0.74        0.64425  4.163538e-70         1.0
# 15  Salt Pepper Noise AUC 0.70        0.66750  9.820298e-76         1.0
# 16  Salt Pepper Noise AUC 0.66        0.68325  1.117181e-79         1.0
# 17  Salt Pepper Noise AUC 0.62        0.68475  2.412229e-80         1.0
# 18  Salt Pepper Noise AUC 0.58        0.70450  1.952336e-86         1.0
# 19      Speckle Noise AUC 0.86        0.00000  1.000000e+00         0.0
# 20      Speckle Noise AUC 0.82        0.30025  3.789804e-14         1.0
# 21      Speckle Noise AUC 0.78        0.44650  3.419539e-32         1.0
# 22      Speckle Noise AUC 0.74        0.57100  1.473938e-55         1.0
# 23      Speckle Noise AUC 0.70        0.65325  7.686022e-74         1.0
# 24      Speckle Noise AUC 0.66        0.71525  5.466974e-90         1.0
# 25      Speckle Noise AUC 0.62        0.61250  1.920754e-62         1.0
# 26      Speckle Noise AUC 0.58        0.61425  1.382635e-63         1.0
# 27       Contrast Inc AUC 0.86        0.00000  1.000000e+00         0.0
# 28       Contrast Inc AUC 0.82        0.16975  1.660442e-04         1.0
# 29       Contrast Inc AUC 0.78        0.25300  8.744124e-10         1.0
# 30       Contrast Inc AUC 0.74        0.28700  2.007894e-13         1.0
# 31       Contrast Inc AUC 0.70        0.31350  1.172384e-15         1.0
# 32       Contrast Inc AUC 0.66        0.35450  1.493503e-17         1.0
# 33       Contrast Inc AUC 0.62        0.44875  1.102190e-30         1.0
# 34       Contrast Inc AUC 0.58        0.48650  5.455681e-37         1.0
# 35       Contrast Dec AUC 0.86        0.00000  1.000000e+00         0.0
# 36       Contrast Dec AUC 0.82        0.37350  4.223977e-21         1.0
# 37       Contrast Dec AUC 0.78        0.48325  1.038574e-37         1.0
# 38       Contrast Dec AUC 0.74        0.52950  7.303819e-46         1.0
# 39       Contrast Dec AUC 0.70        0.58125  2.143424e-56         1.0
# 40       Contrast Dec AUC 0.66        0.61500  5.077729e-63         1.0
# 41       Contrast Dec AUC 0.62        0.63400  1.657422e-66         1.0
# 42       Contrast Dec AUC 0.58        0.65400  1.000080e-70         1.0
# 43          Gamma Inc AUC 0.86        0.00000  1.000000e+00         0.0
# 44          Gamma Inc AUC 0.82        0.16000  7.618876e-04         1.0
# 45          Gamma Inc AUC 0.78        0.25900  4.044976e-09         1.0
# 46          Gamma Inc AUC 0.74        0.35050  4.620794e-18         1.0
# 47          Gamma Inc AUC 0.70        0.42850  1.085110e-26         1.0
# 48          Gamma Inc AUC 0.66        0.47950  5.691718e-35         1.0
# 49          Gamma Inc AUC 0.62        0.51000  1.003896e-41         1.0
# 50          Gamma Inc AUC 0.58        0.53000  3.365023e-46         1.0
# 51          Gamma Dec AUC 0.86        0.00000  1.000000e+00         0.0
# 52          Gamma Dec AUC 0.82        0.39300  1.085050e-24         1.0
# 53          Gamma Dec AUC 0.78        0.46350  4.127370e-34         1.0
# 54          Gamma Dec AUC 0.74        0.49875  8.025539e-39         1.0
# 55          Gamma Dec AUC 0.70        0.52375  1.272730e-42         1.0
# 56          Gamma Dec AUC 0.66        0.53800  7.546486e-46         1.0
# 57          Gamma Dec AUC 0.62        0.54800  1.000681e-47         1.0
# 58          Gamma Dec AUC 0.58        0.55925  3.238443e-49         1.0
# 59            Magnify AUC 0.86        0.00000  1.000000e+00         0.0
# 60            Magnify AUC 0.82        0.31125  3.947516e-15         1.0
# 61            Magnify AUC 0.78        0.37950  8.515740e-20         1.0
# 62            Magnify AUC 0.74        0.43050  8.179325e-28         1.0
# 63            Magnify AUC 0.70        0.46500  1.318582e-32         1.0
# 64            Magnify AUC 0.66        0.49875  1.222285e-38         1.0
# 65            Magnify AUC 0.62        0.53550  2.512034e-46         1.0
# 66            Magnify AUC 0.58        0.56900  1.820333e-53         1.0
#
#     K-S SM roc
# 0     0.860981
# 1     0.809276
# 2     0.766403
# 3     0.724283
# 4     0.684262
# 5     0.860981
# 6     0.814103
# 7     0.759841
# 8     0.721294
# 9     0.677330
# 10    0.637551
# 11    0.860981
# 12    0.810208
# 13    0.770942
# 14    0.738923
# 15    0.697755
# 16    0.649627
# 17    0.617121
# 18    0.590517
# 19    0.860981
# 20    0.808695
# 21    0.768869
# 22    0.732697
# 23    0.688375
# 24    0.652281
# 25    0.614498
# 26    0.575913
# 27    0.860981
# 28    0.807699
# 29    0.764614
# 30    0.727511
# 31    0.687877
# 32    0.656152
# 33    0.619704
# 34    0.570104
# 35    0.860981
# 36    0.819495
# 37    0.778142
# 38    0.752197
# 39    0.705259
# 40    0.659678
# 41    0.625855
# 42    0.581153
# 43    0.860981
# 44    0.812411
# 45    0.763136
# 46    0.716159
# 47    0.683666
# 48    0.646610
# 49    0.609944
# 50    0.587466
# 51    0.860981
# 52    0.821805
# 53    0.780958
# 54    0.748236
# 55    0.699769
# 56    0.656359
# 57    0.616489
# 58    0.583749
# 59    0.860981
# 60    0.812199
# 61    0.777051
# 62    0.734528
# 63    0.697873
# 64    0.657671
# 65    0.614966
# 66    0.568058

# %%
dataframes = []
# create a separate df for each transform
for transform in TRANSFORMS:
    dataframes.append(df.loc[df["Transform"].str.contains(transform)])
dataframes[0]
# Out:
#        Transform  K-S SM signal   K-S SM pval  K-S SM acc  K-S SM roc
# 0  Blur AUC 0.86        0.00000  1.000000e+00         0.0    0.860981
# 1  Blur AUC 0.82        0.36225  4.053988e-19         1.0    0.809276
# 2  Blur AUC 0.78        0.50700  5.336910e-41         1.0    0.766403
# 3  Blur AUC 0.74        0.55250  1.019237e-49         1.0    0.724283
# 4  Blur AUC 0.70        0.58350  2.987296e-54         1.0    0.684262

# %%
for df_tf in dataframes:
    plt.plot(df_tf["K-S SM roc"], df_tf["K-S SM signal"])
plt.legend(TRANSFORMS, bbox_to_anchor=(1.05, 1.0), loc="upper left")
plt.title("K-S Test on Softmax Inputs: Response to Transforms")
plt.xlabel("ROC-AUC")
plt.ylabel("K-S signal")
plt.show()

# %%
for df_tf in dataframes:
    plt.plot(df_tf["K-S SM roc"], df_tf["K-S SM acc"], alpha=0.8)

plt.legend(TRANSFORMS, bbox_to_anchor=(1.05, 1.0), loc="upper left")
plt.title("K-S Test on Softmax Inputs: Shift Detection Accuracy")
plt.xlabel("ROC-AUC")
plt.ylabel("K-S Accuracy")
plt.show()
